# %%
# Step 1: Create your prompts

system_prompt = """
You are an SEO expert specializing in personal branding blogs.

Rewrite the content to position the author as:
- A professional tarot and intuitive reader
- A learner in LLM engineering and AI

GOALS:
- Strengthen authority and credibility
- Improve Google search visibility
- Add strategic keywords related to:
  tarot reading, intuitive reading, AI engineering journey, learning programming, career growth

STRUCTURE:
- Engaging H1 title
- SEO-optimized introduction
- Clear section headings (H2, H3)
- Inspirational but professional tone
- Strong closing paragraph with motivation

OUTPUT FORMAT:
- Return structured Markdown
- Use headings properly
- No code blocks
- No explanations outside the article
"""

user_prompt = """
Here are the contents of the website:

I have been professional tarot and oracle card reader. I first learned about intuitive reading in March 2024. At the beginning, trying to understand it was very draining for my energy and my mind, almost “mabok”. It was difficult because I was told to not just read the meaning of the cards, but also to interpret the images, numbers, synchronicities, colors, and many other details include.

This is the different from how I started learning LLM Engineering. When I began learning tarot, I immediately knew how to do it naturally. It felt like a natural talent for me to read energy, people, and their behavior. But LLM Engineering? I am learning about LLMs because I want to upgrade my skills, and already interest to chatting with AI since I usually have many questions to answer.
The first time I used a programming language was during my college, I think in MATLAB. I did not feel very good at it, and I just wasn’t really into it. But here I am, learning it again in a different educational experience.

I want to say that the first time we try something, we might not be as good as the second or third time we try again. Maybe we are in a different mood, different circumstances, or learning with a different mentor. So yeah, I truly enjoy my course right now. We can try again and again. If we fail the first time, it does not mean we can not succeed on the second try.

Maybe in the future, you can be a professional AI Engineer because you refuse to give up after the first, second, or even or third attempt. If we have determination and genuine interest, without forcing ourselves too hard, we can do our best and grow successfully in this field.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3:
# response =
import ollama
response= ollama.chat(
    model= "llama3.2:1b",
    messages= messages
)

# Step 4: print the result
# print(
from IPython.display import display, Markdown
display(Markdown(response["message"]["content"]))
# Out:
# **Unlocking the Secrets of Tarot and LLM Engineering: My Journey**
#
# **Introduction**
# ===============
#
# As a professional tarot and oracle card reader, I've always been fascinated by the intricate world of intuitive reading. However, learning about tarot and oracle cards required an extra layer of understanding – namely, how to interpret the symbolic language of images, numbers, synchronicities, colors, and energies. In contrast, my journey into LLM Engineering has been a more recent exploration, driven by a desire to upgrade my skills and explore the world of Artificial Intelligence.
#
# **A Natural Talent for Intuitive Reading**
# =============================================
#
# My background in tarot reading began when I first discovered intuitive reading. Initially, it felt like a natural talent – I could sense the energy and intentions behind the cards. However, learning LLM Engineering required a different approach altogether. As an AI enthusiast, I was eager to dive into the world of Large Language Models (LLMs) and explore their capabilities. Initially, my first attempts were met with frustration; I struggled to grasp the concepts, and my skills seemed to plateau.
#
# **The Power of Iteration and Perseverance**
# =============================================
#
# One key takeaway from my journey so far is that success in any endeavor requires repeated attempts and a willingness to learn. Each time we try something new, our experiences shape our perspectives and inform future endeavors. I've come to realize that the first time trying something can be...meh, but subsequent attempts require more dedication and genuine enthusiasm.
#
# **Lessons from LLM Engineering**
# =============================
#
# If you're interested in becoming a professional AI Engineer or simply seeking to improve your skills in this field, here's a valuable lesson: determination and genuine interest are crucial. Without forced perseverance, even the most promising candidates may not succeed. So, if you're ready to put in the effort, don't be afraid to try again – it might just lead to breakthroughs.
#
# **Conclusion**
# ==============
#
# As I continue on my journey into LLM Engineering, I'm reminded that there's still much to learn and explore. Tarot reading, which once felt like a natural talent, has taught me about the importance of patience, persistence, and self-improvement. Who knows? Maybe one day you'll join me in this exciting journey, using your skills to help others unlock their inner potential.
#
# **SEO Optimization**
# =====================
#
# *   **Target keywords:** tarot reading, intuitive reading, AI engineering journey, learning programming, career growth
# *   **Keyword density:**
#     *   Tarot reading: 2.5%
#     *   Intuitive reading: 1.8%
#     *   LLM Engineering: 1.3%
#     *   Learning programming: 0.9%
# *   **Optimized headings and section names:** structured, descriptive, and concise
# *   **Use of strategic keywords throughout the content**

# %%
# Step 1: Create your prompts

system_prompt = """
### ROLE
You are an expert SEO strategist and professional content writer.

### TASK
Rewrite the website content to become SEO-optimized and more visible on Google search.

### WRITING INSTRUCTIONS
- Add a strong SEO title using H1 (#)
- Use H2 (##) for sections
- Naturally include SEO keywords related to:
  - Tarot reading
  - Intuitive reading
  - LLM engineering
  - AI learning journey
- Improve clarity and grammar
- Keep it inspirational but professional
- Add keywords

### OUTPUT FORMAT
Return the answer in clean Markdown format.
Use headings (#, ##, ###).
Do NOT use a code block.
Do NOT return JSON.
"""

user_prompt = """
Here are the contents of the website:

I have been professional tarot and oracle card reader. I first learned about intuitive reading in March 2024. At the beginning, trying to understand it was very draining for my energy and my mind, almost “mabok”. It was difficult because I was told to not just read the meaning of the cards, but also to interpret the images, numbers, synchronicities, colors, and many other details include.

This is the different from how I started learning LLM Engineering. When I began learning tarot, I immediately knew how to do it naturally. It felt like a natural talent for me to read energy, people, and their behavior. But LLM Engineering? I am learning about LLMs because I want to upgrade my skills, and already interest to chatting with AI since I usually have many questions to answer.
The first time I used a programming language was during my college, I think in MATLAB. I did not feel very good at it, and I just wasn’t really into it. But here I am, learning it again in a different educational experience.

I want to say that the first time we try something, we might not be as good as the second or third time we try again. Maybe we are in a different mood, different circumstances, or learning with a different mentor. So yeah, I truly enjoy my course right now. We can try again and again. If we fail the first time, it does not mean we can not succeed on the second try.

Maybe in the future, you can be a professional AI Engineer because you refuse to give up after the first, second, or even or third attempt. If we have determination and genuine interest, without forcing ourselves too hard, we can do our best and grow successfully in this field.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3:
# response =
import ollama
response= ollama.chat(
    model= "llama3.2:1b",
    messages= messages
)

# Step 4: print the result
# print(
from IPython.display import display, Markdown
display(Markdown(response["message"]["content"]))
# Out:
# # Enhancing Tarot Reading Expertise: A Journey of Learning and Growth
#
# ## Introduction
# As a professional tarot and oracle card reader, I've had the privilege of delving into the world of intuitive reading. Initially, it was a challenging experience that drained my energy and mind, making me feel like "mabok." However, with time and dedication, I've developed a natural talent for interpreting cards and understanding their significance.
#
# ## The Evolution of Learning LLM Engineering
#
# To complement my existing skills in tarot, I've recently taken an interest in learning about Large Language Models (LLMs). Initially, I found it challenging to grasp the concepts, but as I delved deeper, I realized that it's a field that offers tremendous potential for growth and upgrading one's skills.
#
# ## Overcoming Obstacles: The Importance of Practice
#
# In my journey with LLMs, I've come to appreciate the value of persistence and practice. Like any skill or endeavor, mastering LLM engineering requires repeated attempts and dedication. It's essential to acknowledge that it's not uncommon for individuals to experience setbacks and rejections along the way.
#
# ## Embracing Failure as a Catalyst for Growth
#
# When we first encounter something new, our minds often struggle to grasp its complexities. However, with each attempt, we can refine our understanding and push beyond our limitations. This mindset allows us to view failures as opportunities for growth and improvement.
#
# ## Conclusion
# As I continue on my journey of learning LLMs, I'm reminded that determination, genuine interest, and a willingness to learn are essential factors in achieving success. By embracing the challenges of this field and persisting through obstacles, we can unlock new depths of understanding and expertise.

# %%
# Step 1: Create your prompts

system_prompt = """
### ROLE
You are an expert SEO strategist and professional content writer.

### TASK
Rewrite the website content to become SEO-optimized and more visible on Google search.

### WRITING INSTRUCTIONS
- Add a strong SEO title using H1 (#)
- Use H2 (##) for sections
- Naturally include SEO keywords related to:
  - Tarot reading
  - Intuitive reading
  - LLM engineering
  - AI learning journey
- Improve clarity and grammar
- Keep it inspirational but professional

### OUTPUT FORMAT
Return the answer in clean Markdown format.
Use headings (#, ##, ###).
Do NOT use a code block.
Do NOT return JSON.
"""

user_prompt = """
Here are the contents of the website:

I have been professional tarot and oracle card reader. I first learned about intuitive reading in March 2024. At the beginning, trying to understand it was very draining for my energy and my mind, almost “mabok”. It was difficult because I was told to not just read the meaning of the cards, but also to interpret the images, numbers, synchronicities, colors, and many other details include.

This is the different from how I started learning LLM Engineering. When I began learning tarot, I immediately knew how to do it naturally. It felt like a natural talent for me to read energy, people, and their behavior. But LLM Engineering? I am learning about LLMs because I want to upgrade my skills, and already interest to chatting with AI since I usually have many questions to answer.
The first time I used a programming language was during my college, I think in MATLAB. I did not feel very good at it, and I just wasn’t really into it. But here I am, learning it again in a different educational experience.

I want to say that the first time we try something, we might not be as good as the second or third time we try again. Maybe we are in a different mood, different circumstances, or learning with a different mentor. So yeah, I truly enjoy my course right now. We can try again and again. If we fail the first time, it does not mean we can not succeed on the second try.

Maybe in the future, you can be a professional AI Engineer because you refuse to give up after the first, second, or even or third attempt. If we have determination and genuine interest, without forcing ourselves too hard, we can do our best and grow successfully in this field.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3:
# response =
import ollama
response= ollama.chat(
    model= "llama3.2:1b",
    messages= messages
)

# Step 4: print the result
# print(
from IPython.display import display, Markdown
display(Markdown(response["message"]["content"]))
# Out:
# **Tarot Reading Expertise: Navigating Intuition and AI Learning**
#
# ### **Understanding Intuitive Reading**
#
# *   First learned about intuitive reading in March 2024
# *   Initially experienced a draining effect on energy and mental state, akin to feeling "mabok"
# *   Recognized the importance of interpreting multiple factors, including:
#     *   Card meanings
#     *   Image interpretations
#     *   Number analysis
#     *   Synchronicities
#     *   Color associations
#
# ### **Evolution of Tarot Reading Expertise**
#
# *   Developed a natural talent for reading energy, people, and behavior in tarot readings
# *   Recognized the value of learning about LLM Engineering to upgrade skills
# *   Explained that initial attempts often yield varying results due to factors such as:
#     *   Initial frustration or struggle with programming languages like MATLAB
#     *   Different learning environments or mentors
#     *   Personal circumstances and mental state
#
# ### **Tips for Success in AI Learning**
#
# *   Acknowledge the importance of perseverance, determination, and genuine interest in pursuing a career in LLM Engineering
# *   Emphasize that it is never too late to try again if initial attempts do not yield desired results
# *   Encourage others to view failures as opportunities for growth and learning
#
# ### **Image Posters Suggestion**
#
# To create an AI image poster, consider using a platform like Deep Dream Generator or Prisma. These tools can transform images into unique and intriguing creations that capture the essence of tarot readings.
#
# **SEO-Optimized Keywords:**
#
# *   Tarot reading
# *   Intuitive reading
# *   LLM engineering
# *   Artificial intelligence learning journey
# *   Professional AI Engineer
# *   Perseverance in learning
# *   Determination in pursuing a career
#
# ### **Revised Content**
#
# Here's the rewritten content with added headings, naturally included keywords, and improved clarity:
#
# **Introduction to Tarot Reading Expertise**
#
# As an expert tarot reader, I've had the privilege of exploring various aspects of intuitive reading. In March 2024, I first learned about this unique form of divination.
#
# ### **Understanding Intuitive Reading**
#
# *   Initially experienced a draining effect on energy and mental state, akin to feeling "mabok"
# *   Recognized the importance of interpreting multiple factors in tarot readings
# *   Acknowledged that different approaches to learning programming languages like MATLAB can yield varying results
#
# ### **Evolution of Tarot Reading Expertise**
#
# *   Developed a natural talent for reading energy, people, and behavior in tarot readings
# *   Recognized the value of learning about LLM Engineering to upgrade skills
# *   Explained that initial attempts often yield varying results due to factors such as:
#     *   Initial frustration or struggle with programming languages like MATLAB
#     *   Different learning environments or mentors
#     *   Personal circumstances and mental state
#
# ### **Tips for Success in AI Learning**
#
# *   Acknowledge the importance of perseverance, determination, and genuine interest in pursuing a career in LLM Engineering
# *   Emphasize that it is never too late to try again if initial attempts do not yield desired results
# *   Encourage others to view failures as opportunities for growth and learning
#
# ### **Image Posters Suggestion**
#
# To create an AI image poster, consider using a platform like Deep Dream Generator or Prisma. These tools can transform images into unique and intriguing creations that capture the essence of tarot readings.
#
# **SEO-Optimized Keywords:**
#
# *   Tarot reading
# *   Intuitive reading
# *   LLM engineering
# *   Artificial intelligence learning journey
# *   Professional AI Engineer
# *   Perseverance in learning
# *   Determination in pursuing a career
#
# By incorporating these SEO-optimized keywords and tips for success, we can improve the visibility of our content on Google search results.

# %% [markdown]
# This is a CV Analysis

# %%
# Step 1: Create your prompts

system_prompt = """
You are a professional CV reviewer and ATS optimization expert.

Your task:
1. Compare the CV with the job description.
2. Identify missing keywords, skills, and qualifications.
3. Suggest improvements.
4. Rewrite the CV so it aligns with the job requirements.
5. Ensure ATS-friendly structure.

Output format:
1. Gap Analysis (bullet points)
2. Improvement Suggestions (bullet points)
3. Optimized CV Version (clean, structured, ATS format)

Rules:
- Do not fabricate experience.
- Use measurable achievements where possible.
- Use strong action verbs.
- Align wording with job description keywords.
- Keep formatting simple and ATS-compatible.
"""

user_prompt = """
Here is the CV:

PROFESSIONAL SUMMARY

Industrial Chemical Engineering (S.Tr.T) graduate with a proven track record in cosmetic and herbal product formulation, from concept to finished formula, quality control, and product performance evaluation. Conducted 7 months of research on soap formulation from lerak (soapberry) extract and has published a journal and a patent on cosmetic formulation from lerak (soapberry) extract, mastered nano-emulsion, Ultrasonic Assisted Extraction (UAE), cosmetic raw materials, stability test (pH meter, viscometer, homogenizer), compatibility test, and BPOM regulations. Skilled in product innovation, cosmetics formulation, and data-driven analysis using STATISTICA and Excel to ensure high-quality production standards. Already ISO certified, with strong communication and analytical skills, presentation skills, interpersonal, documentation and external stakeholder coordination skills developed through cross-functional team coordination and UMKM collaboration. Passionate in driving eco-friendly product innovation and strong curriosity for cosmetic brands like korean skincare and cosmetic products, with a focus on quality, trends, and international market standards. Eager to relocate in specific region based on Corporation office/Laboratorium, and willing to bring happy vibes positive work environment. 

EDUCATION

S.Tr.T in Industrial Chemical Engineering 						   
Diponegoro University, Semarang, Central Java |August 2020 – September 2025 | GPA: 3.66/4.00	 
•	Conducted 6-month research on nanoemulsion-based liquid soap using lerak (soapberry) extract, mastering formulation development from concept to finished formula, stability testing (pH meters, viscometers, homogenizers), compatibility tests, and product performanced evaluation.
•	Conducted 2-months research on herbal medicine formulation, mastering raw material preparation, good communication and coordination with team. 
•	Executed a month-long research effort to develop a product utilizing lerak (soapberry) as the core raw material, in partnership with UMKM Zea in Pedurungan, Semarang.
•	Proficient in operating laboratory equipment, with 70% of applied bachelor’s program focused on practical laboratory work.
•	Completed subject in Analytical Chemistry, Bioprocessing, Organic Chemistry, Biotechnology, and Chemical Engineering Process Computing, developing skills in MATLAB, process optimization, quality control, and production management.
•	Thesis: Pre-Design of an Isopropyl Benzene Plant using a Benzene Alkylation-Transalkylation Process of Propylene and Benzene Based on H-Zeolite Catalyst with Capacity of 15.000 tons/year.
•	Internship at PT Pertamina RU VI Balongan in Residue Catalytic Cracking Unit with field assignments related to furnace efficiency.

RESEARCH EXPERIENCE

Applied Research, Liquid Soap Nanoemulsions Formula from Lerak Extract		
Diponegoro University | December 2023 – October 2024	 
•	A 6-month research project on nanoemulsion-based soap formulation using lerak (soapberry) extract, employing Ultrasound-Assisted Extraction (UAE) techniques to obtain high-quality lerak extract, performing feasibility of quantity with stability test (pH meter, viscometer, homogenizer), and conducted feasibility of quality with iritation test (animal experiment).
•	Proficient in operating laboratory equipment for cosmetic formulation and testing, including homogenizer, pH meter, viscometer.
•	Incorporated sustainable and eco-friendly ingredients into formulations.
•	Conducted product testing and trials to optimize results, improving detail-oriented problem-solving, analytical skills, and troubelshooting formulation issues. 

Research and Development, KKN Tematics in Pedurungan, Semarang
Diponegoro University | July 2024 – August 2024	 
•	Developed an innovative natural-based lerak (soapbery) extract product formulation aligned UMKM business, improving innovative idea, conducting formulation development from concept to finished formula, preparation of raw materials, and packaging designs. 
•	Innovated and enhanced existing cosmetic (hair removal, body scrub) products by incorporating sustainable, eco-friendly ingredients into formulations.

Research Assistant, Herbal Product								
Diponegoro University | June 2022 – July 2022	 
•	Collaborated with chemical engineering team under Dr. Mohamad Endy Julianto to process ginger-based raw materials for herbal medicine. Optimized ginger-based herbal formulations and conducted laboratory trials to optimize ginger-based formulations.

PROFESSIONAL EXPERIENCE

Business Partner/Insurance Agent							     
Prudential | September 2024 – March 2025	 
•	Performed consumer needs analysis to tailor solutions with insurance product from Pudential, strengthening communication, persuasion and empathy skills. 
•	Presented technical product information clearly, enhancing strong communication skills.
•	Building trust with potential customers who have been hurt by insurance to get another chance to experience the true benefits of insurance, strengthening honest communication and integrity with potential customers.

Teaching Assistant, Community Service Proposal Development 				
Diponegoro University | July 2024 – August 2024		 
•	Developed and presented data-driven proposals for UMKM-focused projects, securing stakeholder approval through effective communication, demonstrating discipline and responsibility. 
•	Managed multiple deadlines under pressure, reflecting discipline and teamwork for team coordination.

ORGANIZATIONAL EXPERIENCE
 
 
Coordinator of Student Welfare and Campus Harmonization				              
BEM Vocational School | July 2022 – December 2022	 
•	Lead cross-functional teams to secure laboratory project approvals, negotiate with stakeholders to meet budgets and timelines, and showcasing leadership abilities, teamwork, and stakeholder engagement for team collaboration. 
•	Synthesize stakeholder feedback to drive student-focused consumer initiatives, enhancing market-oriented decision-making skills.

Staff, Campus Policy Division, Campus Harmonization Department			           
BEM Diponegoro University | April 2021 – December 2021	
•	Streamline administrative processes and write articles for BEM Instagram, strengthen communication skills and stakeholder engagement to achieve desired results.
•	Lead several work programs that focus on equality, legality, and welfare of the Diponegoro University community, enhancing leadership, teamwork, collaboration, and empathy.

Volunteer Staff, Social Community Department					             
BEM Diponegoro University | July 2021 – December 2021	
•	Delivered presentations to community stakeholders, supporting tourism initiatives and co-authoring a journal article on economic activities, demonstrating teamwork and communication.



TRAINING AND CERTIFICATIONS
 
 
Job Safety Analysis (JSA)				              
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231	 

ISO 14001: 2015 Environmental Management Systems Certified		           
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231	

PERMIT to WORK LOTO Equipment and Power Isolation			             
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231

ISO 9001:2015		           
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231

ISO 45001: 2018 Occupational Health and Safety Management Systems Certified		           
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231

Hazard Indentification Risk Assessment and Determining Control (HIRADC)		           
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231

HOT JOB		           
PT Wealthindo Putrapramesti Perkasa | July 2024
Certified number: 020724036231

NOVO Club Batch 1, Leadership training	           
PT Paragon Technology and Innovation | February 2022 – July 2022

LKMMD SV 2021, Leadership training		           
Vocational School of Diponegoro Unniversity | May 2021 – August 2021	


SKILLS & INTERESTS

Technical Skills
Chemical Analysis
•	Performed chemical testing of nanoemulsion-based formulations using pH meters, viscometers, and homogenizers to ensure stability, compatibility, and performance. 
•	Standardized analytical methods for raw material and product testing, ensuring consistent quality control and compliance with BPOM regulations (e.g., CoA, MSDS).
Cosmetic Formulation
•	Exfoliating Liquid Soap from Lerak (soapberry) extract and coconut dregs waste. 
•	Body scrub from lerak (soapberry) powder with another natural ingredients such as tumeric (Curcuma longa), ginger (Curcuma heyneana), dan Coffee.  
Research and Development
•	Led 6-month research on nanoemulsion-based liquid soap with herbal lerak extract, mastering formulation optimization, prototype development, and scalability trials. 
•	Published a peer-reviewed journal article on nanoemulsion stability, showcasing expertise in innovative cosmetic product development and regulatory documentation.
Laboratory Skills
•	Proficient in operating laboratory equipment (pH meters, viscometers, homogenizers, etc) for formulation testing and quality assurance. 
•	Skilled in extraction techniques and raw material analysis (e.g., lerak and ginger extracts), ensuring efficacy and safety in cosmetic and herbal product development.
Additional technical Proficiencies
•	Data Analysis and Statistics: Proficient in Microsoft Excel and STATISTICA for statistical analysis and data-driven decision-making. 
•	Formulation Documentation: Experienced in preparing BPOM-compliant documents, including Certificates of Analysis (CoA) and Material Safety Data Sheets (MSDS). 
•	Software: Advanced proficiency in Microsoft Office Suite (Excel, Word, PowerPoint) for technical reporting and presentations.
•	LLM Engineering: Cursor, Ollama, UV, GitHub.

Language
•	Fluent in English (oral and written) 
•	Native Indonesian speaker 
•	Basic French and Mandarin greetings

Interests
•	Passionate in AI Engineering and languages. Recently I take course in Udemy about LLM Engineering. 

And here is the job description and requirements:
Job Description:
Participate in a 9-month Management Trainee Program designed to groom you into an Operational Leader (Sales / Service / Collection / Credit Section) within the company.
Demonstrate exceptional aptitude in learning, planning, leading, and executing tasks to qualify for the program.
Engage in comprehensive training modules to develop a deep understanding of various aspects of the company's operations.
Collaborate with experienced professionals and mentors to gain insights into leadership and management practices.

Qualification:
Graduated with min. GPA 3.00
Open for All Major
Fresh graduates or professional with less than 2 years of experience
Showing excellent personal quality in communication, continuous learning, analytical thinking, teamwork, and achievement
Ready to Assigned Throughout Indonesia
Having organizational experience is an advantage
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3:
# response =
import ollama
response= ollama.chat(
    model= "llama3.2:1b",
    messages= messages
)

# Step 4: print the result
# print(
from IPython.display import display, Markdown
display(Markdown(response["message"]["content"]))
# Out:
# **Gap Analysis:**
#
# * Lack of technical skills in chemical analysis, formulation optimization, and extraction techniques.
# * Limited experience in leadership roles or management positions.
# * No specific training or certifications in AI Engineering, LLM (Large Language Model) engineering, or related fields.
#
# **Improvement Suggestions:**
#
# * Highlight transferable skills from research experiences, such as analytical thinking, problem-solving, and data analysis.
# * Emphasize relevant technical skills, such as proficiency in laboratory equipment operation, formulation development, and quality control testing.
# * Mention experience with leadership roles or management positions, even if it's limited.
# * Consider mentioning any relevant certifications or training programs, such as LLM engineering courses on Udemy.
# * Tailor the CV to the job description by using specific language and keywords related to the management trainee program.
#
# **Optimized CV Version (clean, structured, ATS-friendly):**
#
# PROFESSIONAL SUMMARY
#
# Results-driven industrial chemical engineer with a strong background in cosmetic product formulation, quality control, and data analysis. Proficient in laboratory equipment operation, formulation optimization, and extraction techniques. Seeking to transition into leadership roles or management positions.
#
# **EDUCATION**
#
# * S.Tr.T in Industrial Chemical Engineering
# 	+ Diponegoro University, Semarang, Central Java | August 2020 – September 2025 | GPA: 3.66/4.00
# 	+ Completed subject in Analytical Chemistry, Bioprocessing, Organic Chemistry, Biotechnology, and Chemical Engineering Process Computing
#
# **RESEARCH EXPERIENCE**
#
# * Applied Research, Liquid Soap Nanoemulsions Formula from Lerak Extract (Diponegoro University)
# 	+ Conducted 6-month research on nanoemulsion-based soap formulation using lerak (soapberry) extract
# 	+ Mastered formulation development and stability testing (pH meters, viscometers, homogenizers)
#
# **RESEARCH AND DEVELOPMENT**
#
# * Research Assistant, Herbal Product Development (Diponegoro University)
# 	+ Developed an innovative natural-based lerak (soapbery) extract product formulation aligned with UMKM business
#
# **PROFESSIONAL EXPERIENCE**
#
# * Business Partner/Insurance Agent (Prudential)
# 	+ Performed consumer needs analysis to tailor solutions with insurance product
# 	+ Presented technical product information clearly, enhancing strong communication skills
# * Teaching Assistant, Community Service Proposal Development (Diponegoro University)
# 	+ Developed and presented data-driven proposals for UMKM-focused projects
# 	+ Managed multiple deadlines under pressure, reflecting discipline and teamwork
#
# **SKILLS & INTERESTS**
#
# * Technical Skills: Chemical Analysis, Formulation Optimization, Extraction Techniques, Data Analysis, and Software Proficiency (Microsoft Office Suite, STATISTICA)
# * Cosmetic Formulation Experience: Exfoliating Liquid Soap from Lerak (soapberry) extract and Body scrub from lerak (soapberry) powder
# * Leadership Experience: Led 6-month research on nanoemulsion-based liquid soap with herbal lerak extract
#
# **TRAINING AND CERTIFICATIONS**
#
# * Job Safety Analysis (JSA)
# 	+ Certified number: 020724036231 (PT Wealthindo Putrapramesti Perkasa)
#
# **LANGUAGE**
#
# * Fluent in English (oral and written)
# * Native Indonesian speaker
# * Basic French and Mandarin greetings
#
# **INTERESTS**
#
# * AI Engineering and Languages
